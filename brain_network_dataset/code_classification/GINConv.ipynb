# %%
import torch
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GINConv,global_mean_pool
from torch.nn import Linear
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler

# %%
# 加载数据
node_csv_path = r"D:\ttt\a\node_total.csv"
links_csv_path = r"D:\ttt\a\link_total.csv"
labels_csv_path = r"D:\ttt\a\label_total.csv"

# %%
node_df = pd.read_csv(node_csv_path)
links_df = pd.read_csv(links_csv_path)
labels_df = pd.read_csv(labels_csv_path)

# %%
graph_data_list = []

# %%
# 遍历每个会话
for session_id in tqdm(node_df['sessionId'].unique()):
    # 节点特征
    session_nodes = node_df[node_df['sessionId'] == session_id]
    node_features = session_nodes[['degree', 'cluster','efficiency']].values
    # 对节点特征进行标准化
    scaler = StandardScaler()
    node_features_normalized = scaler.fit_transform(node_features)
    # 将标准化后的特征转换为 PyTorch 张量
    node_features_tensor = torch.tensor(node_features_normalized, dtype=torch.float)
    
    #边索引
    session_edges = links_df[links_df['sessionId'] == session_id]
    edge_index = torch.tensor([session_edges['source'].values - 1, 
                               session_edges['target'].values - 1], 
                              dtype=torch.long)
    
    #标签
    label = labels_df[labels_df['sessionId'] == session_id]['label'].iloc[0]
    label_tensor = torch.tensor([label], dtype=torch.float)

    data = Data(x=node_features_tensor, edge_index=edge_index, y=label_tensor)
    graph_data_list.append(data)
# Out:
# 100%|██████████| 680/680 [00:00<00:00, 693.46it/s]

# %%
for i in range(680):
    print(graph_data_list[i])
# Out:
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 44], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 60], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 51], y=[1])
# Data(x=[24, 3], edge_index=[2, 58], y=[1])
# Data(x=[24, 3], edge_index=[2, 52], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 92], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 53], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 72], y=[1])
# Data(x=[24, 3], edge_index=[2, 46], y=[1])
# Data(x=[24, 3], edge_index=[2, 84], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 129], y=[1])
# Data(x=[24, 3], edge_index=[2, 155], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 45], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 43], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 56], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 51], y=[1])
# Data(x=[24, 3], edge_index=[2, 46], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 86], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 51], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 66], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 81], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 128], y=[1])
# Data(x=[24, 3], edge_index=[2, 153], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 55], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 55], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 50], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 85], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 62], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 79], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 122], y=[1])
# Data(x=[24, 3], edge_index=[2, 146], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 81], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 43], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 77], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 114], y=[1])
# Data(x=[24, 3], edge_index=[2, 140], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 43], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 43], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 77], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 77], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 107], y=[1])
# Data(x=[24, 3], edge_index=[2, 137], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 100], y=[1])
# Data(x=[24, 3], edge_index=[2, 44], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 71], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 97], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 58], y=[1])
# Data(x=[24, 3], edge_index=[2, 68], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 92], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 55], y=[1])
# Data(x=[24, 3], edge_index=[2, 60], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 90], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 49], y=[1])
# Data(x=[24, 3], edge_index=[2, 53], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 85], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 49], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 95], y=[1])
# Data(x=[24, 3], edge_index=[2, 61], y=[1])
# Data(x=[24, 3], edge_index=[2, 57], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 49], y=[1])
# Data(x=[24, 3], edge_index=[2, 78], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 46], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 92], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 72], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 44], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 89], y=[1])
# Data(x=[24, 3], edge_index=[2, 56], y=[1])
# Data(x=[24, 3], edge_index=[2, 54], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 83], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 67], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 85], y=[1])
# Data(x=[24, 3], edge_index=[2, 52], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 58], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 67], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 81], y=[1])
# Data(x=[24, 3], edge_index=[2, 43], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 54], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 61], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 69], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 62], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 53], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 55], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 63], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 5], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 102], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 71], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 45], y=[1])
# Data(x=[24, 3], edge_index=[2, 99], y=[1])
# Data(x=[24, 3], edge_index=[2, 45], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 69], y=[1])
# Data(x=[24, 3], edge_index=[2, 48], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 94], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 65], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 93], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 62], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 85], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 54], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 50], y=[1])
# Data(x=[24, 3], edge_index=[2, 81], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 85], y=[1])
# Data(x=[24, 3], edge_index=[2, 68], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 51], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 142], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 35], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 44], y=[1])
# Data(x=[24, 3], edge_index=[2, 79], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 76], y=[1])
# Data(x=[24, 3], edge_index=[2, 65], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 4], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 44], y=[1])
# Data(x=[24, 3], edge_index=[2, 30], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 49], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 13], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 136], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 39], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 5], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 59], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 4], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 42], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 41], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 123], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 5], y=[1])
# Data(x=[24, 3], edge_index=[2, 32], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 70], y=[1])
# Data(x=[24, 3], edge_index=[2, 5], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 2], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 38], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 31], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 119], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 4], y=[1])
# Data(x=[24, 3], edge_index=[2, 27], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 11], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 45], y=[1])
# Data(x=[24, 3], edge_index=[2, 6], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 67], y=[1])
# Data(x=[24, 3], edge_index=[2, 3], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 71], y=[1])
# Data(x=[24, 3], edge_index=[2, 36], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 2], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 5], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 34], y=[1])
# Data(x=[24, 3], edge_index=[2, 8], y=[1])
# Data(x=[24, 3], edge_index=[2, 10], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 9], y=[1])
# Data(x=[24, 3], edge_index=[2, 21], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 110], y=[1])
# Data(x=[24, 3], edge_index=[2, 7], y=[1])
# Data(x=[24, 3], edge_index=[2, 20], y=[1])
# Data(x=[24, 3], edge_index=[2, 3], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 4], y=[1])
# Data(x=[24, 3], edge_index=[2, 12], y=[1])
# Data(x=[24, 3], edge_index=[2, 19], y=[1])
# Data(x=[24, 3], edge_index=[2, 26], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 28], y=[1])
# Data(x=[24, 3], edge_index=[2, 145], y=[1])
# Data(x=[24, 3], edge_index=[2, 60], y=[1])
# Data(x=[24, 3], edge_index=[2, 37], y=[1])
# Data(x=[24, 3], edge_index=[2, 81], y=[1])
# Data(x=[24, 3], edge_index=[2, 75], y=[1])
# Data(x=[24, 3], edge_index=[2, 134], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 25], y=[1])
# Data(x=[24, 3], edge_index=[2, 143], y=[1])
# Data(x=[24, 3], edge_index=[2, 55], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 73], y=[1])
# Data(x=[24, 3], edge_index=[2, 68], y=[1])
# Data(x=[24, 3], edge_index=[2, 128], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 22], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 23], y=[1])
# Data(x=[24, 3], edge_index=[2, 141], y=[1])
# Data(x=[24, 3], edge_index=[2, 47], y=[1])
# Data(x=[24, 3], edge_index=[2, 29], y=[1])
# Data(x=[24, 3], edge_index=[2, 70], y=[1])
# Data(x=[24, 3], edge_index=[2, 57], y=[1])
# Data(x=[24, 3], edge_index=[2, 120], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 16], y=[1])
# Data(x=[24, 3], edge_index=[2, 18], y=[1])
# Data(x=[24, 3], edge_index=[2, 134], y=[1])
# Data(x=[24, 3], edge_index=[2, 40], y=[1])
# Data(x=[24, 3], edge_index=[2, 24], y=[1])
# Data(x=[24, 3], edge_index=[2, 61], y=[1])
# Data(x=[24, 3], edge_index=[2, 53], y=[1])
# Data(x=[24, 3], edge_index=[2, 112], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 14], y=[1])
# Data(x=[24, 3], edge_index=[2, 15], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 132], y=[1])
# Data(x=[24, 3], edge_index=[2, 33], y=[1])
# Data(x=[24, 3], edge_index=[2, 17], y=[1])
# Data(x=[24, 3], edge_index=[2, 54], y=[1])
# Data(x=[24, 3], edge_index=[2, 49], y=[1])
# Data(x=[24, 3], edge_index=[2, 106], y=[1])

# %%
class GraphBinaryClassificationNet(torch.nn.Module):
    def __init__(self):
        super(GraphBinaryClassificationNet, self).__init__()
        self.conv1 = GINConv(Linear(3, 128))
        self.conv2 = GINConv(Linear(128, 128))
        self.conv3 = GINConv(Linear(128, 256))
        self.lin1 = Linear(256, 128)
        self.lin2 = Linear(128, 64)
        self.lin3 = Linear(64, 1)

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        x = F.relu(self.conv1(x, edge_index))
        x = F.relu(self.conv2(x, edge_index))
        x = F.relu(self.conv3(x, edge_index))
        x = global_mean_pool(x, batch)
        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = torch.sigmoid(self.lin3(x)).squeeze(1)
        return x

# %%
def train(train_loader, model, optimizer, crit):
    model.train()
    loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        output = model(data)
        label = data.y.float()  # Ensure labels are float
        loss = crit(output, label)
        loss.backward()
        loss_all += data.num_graphs * loss.item()
        optimizer.step()
    return loss_all / len(train_loader)

# %%
def evaluate(loader, model):
    model.eval()
    predictions, labels = [], []

    with torch.no_grad():
        for data in loader:
            pred = model(data)
            label = data.y
            predictions.extend(pred.numpy())
            labels.extend(label.numpy())

    predictions = np.array(predictions)
    labels = np.array(labels)
    return roc_auc_score(labels, predictions)

# %%
# Cross-validation
k = 5  # Number of folds for cross-validation
kf = KFold(n_splits=k, shuffle=True, random_state=42)
auc_scores = []

# %%
for train_index, test_index in kf.split(graph_data_list):
    train_data = [graph_data_list[i] for i in train_index]
    test_data = [graph_data_list[i] for i in test_index]

    train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

    # Initialize model, optimizer, and loss function
    model = GraphBinaryClassificationNet()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    crit = torch.nn.BCELoss()

    # Train the model
    for epoch in range(100):
        train_loss = train(train_loader, model, optimizer, crit)

    # Evaluate the model
    auc_score = evaluate(test_loader, model)
    auc_scores.append(auc_score)
    print(f"Fold AUC Score: {auc_score}")
# Out:
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.8340943683409436
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.8492321003677266
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.845446679645252
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.8524122807017543
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.8806067172264356

# %%
avg_auc_score = np.mean(auc_scores)
print("Average AUC Score:", avg_auc_score)
# Out:
# Average AUC Score: 0.8620538834196679
