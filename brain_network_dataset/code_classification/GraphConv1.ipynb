# %%
import torch
from torch_geometric.data import Data, DataLoader
from torch_geometric.nn import GraphConv, TopKPooling, global_mean_pool
from torch.nn import Linear
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from torch.nn import Linear, Parameter
import math

# %%
node_csv_path = r"D:\plot\node_total_1.csv"
links_csv_path = r"D:\plot\link_total.csv"
labels_csv_path = r"D:\plot\label_total.csv"
edge_attr_csv_path = r"D:\plot\attr_total.csv"

# %%
node_df = pd.read_csv(node_csv_path)
links_df = pd.read_csv(links_csv_path)
edge_feature_df = pd.read_csv(edge_attr_csv_path)
labels_df = pd.read_csv(labels_csv_path)

# %%
graph_data_list = []

# %%
for session_id in tqdm(node_df['sessionId'].unique()):
    # 节点特征
    session_nodes = node_df[node_df['sessionId'] == session_id]
    node_features = session_nodes[['degree']].values
    
    # 对节点特征进行标准化
    scaler = StandardScaler()
    node_features_normalized = scaler.fit_transform(node_features)
    
    # 将标准化后的特征转换为 PyTorch 张量
    node_features_tensor = torch.tensor(node_features_normalized, dtype=torch.float)

    # 边索引
    session_edges = links_df[links_df['sessionId'] == session_id]
    edge_index = torch.tensor([session_edges['source'].values - 1, 
                               session_edges['target'].values - 1], 
                              dtype=torch.long)

    # 边特征
    edge_features = edge_feature_df[edge_feature_df['sessionId'] == session_id]['edge_feature'].values
    
    # 对边特征进行标准化
    edge_scaler = StandardScaler()
    edge_features_normalized = edge_scaler.fit_transform(edge_features.reshape(-1, 1))
    
    # 将标准化后的边特征转换为 PyTorch 张量
    edge_attr_tensor = torch.tensor(edge_features_normalized, dtype=torch.float)

    # 标签
    label = labels_df[labels_df['sessionId'] == session_id]['label'].iloc[0]
    label_tensor = torch.tensor([label], dtype=torch.float)

    # 创建图数据对象
    data = Data(x=node_features_tensor, edge_index=edge_index, y=label_tensor, edge_attr=edge_attr_tensor)
    graph_data_list.append(data)
# Out:
# 100%|██████████| 530/530 [00:01<00:00, 517.50it/s]

# %%
for i in range(530):
    print(graph_data_list[i])
# Out:
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 48], edge_attr=[48, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 44], edge_attr=[44, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 60], edge_attr=[60, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 63], edge_attr=[63, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 51], edge_attr=[51, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 58], edge_attr=[58, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 92], edge_attr=[92, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 53], edge_attr=[53, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 72], edge_attr=[72, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 46], edge_attr=[46, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 84], edge_attr=[84, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 129], edge_attr=[129, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 155], edge_attr=[155, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 45], edge_attr=[45, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 43], edge_attr=[43, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 56], edge_attr=[56, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 59], edge_attr=[59, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 51], edge_attr=[51, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 46], edge_attr=[46, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 86], edge_attr=[86, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 51], edge_attr=[51, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 66], edge_attr=[66, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 39], edge_attr=[39, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 81], edge_attr=[81, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 128], edge_attr=[128, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 153], edge_attr=[153, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 55], edge_attr=[55, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 55], edge_attr=[55, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 85], edge_attr=[85, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 48], edge_attr=[48, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 62], edge_attr=[62, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 79], edge_attr=[79, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 122], edge_attr=[122, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 146], edge_attr=[146, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 39], edge_attr=[39, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 48], edge_attr=[48, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 81], edge_attr=[81, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 43], edge_attr=[43, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 59], edge_attr=[59, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 77], edge_attr=[77, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 114], edge_attr=[114, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 140], edge_attr=[140, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 43], edge_attr=[43, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 43], edge_attr=[43, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 33], edge_attr=[33, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 77], edge_attr=[77, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 59], edge_attr=[59, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 77], edge_attr=[77, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 107], edge_attr=[107, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 137], edge_attr=[137, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 33], edge_attr=[33, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 95], edge_attr=[95, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 61], edge_attr=[61, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 57], edge_attr=[57, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 39], edge_attr=[39, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 63], edge_attr=[63, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 49], edge_attr=[49, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 78], edge_attr=[78, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 46], edge_attr=[46, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 92], edge_attr=[92, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 72], edge_attr=[72, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 44], edge_attr=[44, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 89], edge_attr=[89, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 56], edge_attr=[56, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 63], edge_attr=[63, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 83], edge_attr=[83, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 67], edge_attr=[67, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 85], edge_attr=[85, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 52], edge_attr=[52, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 33], edge_attr=[33, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 58], edge_attr=[58, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 67], edge_attr=[67, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 63], edge_attr=[63, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 81], edge_attr=[81, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 43], edge_attr=[43, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 54], edge_attr=[54, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 61], edge_attr=[61, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 69], edge_attr=[69, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 62], edge_attr=[62, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 39], edge_attr=[39, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 53], edge_attr=[53, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 55], edge_attr=[55, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 63], edge_attr=[63, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 59], edge_attr=[59, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 5], edge_attr=[5, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 50], edge_attr=[50, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 81], edge_attr=[81, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 85], edge_attr=[85, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 68], edge_attr=[68, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 47], edge_attr=[47, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 51], edge_attr=[51, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 29], edge_attr=[29, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 142], edge_attr=[142, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 35], edge_attr=[35, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 44], edge_attr=[44, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 79], edge_attr=[79, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 76], edge_attr=[76, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 65], edge_attr=[65, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 4], edge_attr=[4, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 44], edge_attr=[44, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 30], edge_attr=[30, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 49], edge_attr=[49, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 13], edge_attr=[13, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 17], edge_attr=[17, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 136], edge_attr=[136, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 39], edge_attr=[39, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 5], edge_attr=[5, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 59], edge_attr=[59, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 4], edge_attr=[4, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 42], edge_attr=[42, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 41], edge_attr=[41, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 15], edge_attr=[15, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 14], edge_attr=[14, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 123], edge_attr=[123, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 5], edge_attr=[5, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 32], edge_attr=[32, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 70], edge_attr=[70, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 5], edge_attr=[5, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 2], edge_attr=[2, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 40], edge_attr=[40, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 26], edge_attr=[26, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 25], edge_attr=[25, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 38], edge_attr=[38, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 31], edge_attr=[31, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 119], edge_attr=[119, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 4], edge_attr=[4, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 27], edge_attr=[27, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 11], edge_attr=[11, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 75], edge_attr=[75, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 45], edge_attr=[45, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 6], edge_attr=[6, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 24], edge_attr=[24, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 33], edge_attr=[33, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 67], edge_attr=[67, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 3], edge_attr=[3, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 71], edge_attr=[71, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 36], edge_attr=[36, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 2], edge_attr=[2, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 19], edge_attr=[19, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 37], edge_attr=[37, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 5], edge_attr=[5, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 22], edge_attr=[22, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 34], edge_attr=[34, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 8], edge_attr=[8, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 10], edge_attr=[10, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 18], edge_attr=[18, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 28], edge_attr=[28, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 9], edge_attr=[9, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 21], edge_attr=[21, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 16], edge_attr=[16, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 110], edge_attr=[110, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 7], edge_attr=[7, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 20], edge_attr=[20, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 3], edge_attr=[3, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 23], edge_attr=[23, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 4], edge_attr=[4, 1], y=[1])
# Data(x=[24, 1], edge_index=[2, 12], edge_attr=[12, 1], y=[1])

# %%
class GraphBinaryClassificationNetWithEdgeFeatures(torch.nn.Module):
    def __init__(self, node_feature_dim=1, edge_feature_dim=1):
        super(GraphBinaryClassificationNetWithEdgeFeatures, self).__init__()
        self.conv1 = GraphConv(node_feature_dim, 128, edge_dim=edge_feature_dim)
        self.conv2 = GraphConv(128, 128, edge_dim=edge_feature_dim)
        self.conv3 = GraphConv(128, 256, edge_dim=edge_feature_dim)
        self.lin1 = Linear(256, 128)
        self.lin2 = Linear(128, 64)
        self.lin3 = Linear(64, 1)
        
        # 为边的重要性评估添加可学习的权重
        self.edge_importance_weights = Parameter(torch.Tensor(edge_feature_dim))
        self.reset_parameters()
        
    def reset_parameters(self):
        torch.nn.init.uniform_(self.edge_importance_weights, -0.1, 0.1)

    def forward(self, data):
        x, edge_index, edge_attr, batch = data.x, data.edge_index, data.edge_attr, data.batch
        
        edge_index, edge_attr = self.learn_and_prune_edges(edge_index, edge_attr)

        x = F.relu(self.conv1(x, edge_index, edge_attr)) 
        x = F.relu(self.conv2(x, edge_index, edge_attr))
        x = F.relu(self.conv3(x, edge_index, edge_attr))
        
        x = global_mean_pool(x, batch)

        x = F.relu(self.lin1(x))
        x = F.relu(self.lin2(x))
        x = torch.sigmoid(self.lin3(x)).squeeze(1)
        
        return x

    def learn_and_prune_edges(self, edge_index, edge_attr, ratio=0.5):
        # 使用可学习的权重评估边的重要性
        edge_scores = (edge_attr * self.edge_importance_weights).sum(dim=-1)
        
        # 选择要保留的边
        _, indices = torch.sort(edge_scores, descending=True)
        num_edges_to_keep = int(indices.size(0) * ratio)
        top_indices = indices[:num_edges_to_keep]
        
        edge_index = edge_index[:, top_indices]
        edge_attr = edge_attr[top_indices]
        
        return edge_index, edge_attr

# %%
def train(train_loader, model, optimizer, crit):
    model.train()
    loss_all = 0
    for data in train_loader:
        optimizer.zero_grad()
        output = model(data)
        label = data.y
        loss = crit(output, label)
        loss.backward()
        loss_all += data.num_graphs * loss.item()
        optimizer.step()
    return loss_all / len(train_loader)

# %%
def evaluate(loader, model):
    model.eval()
    predictions, labels = [], []

    with torch.no_grad():
        for data in loader:
            pred = model(data)
            label = data.y
            predictions.extend(pred.numpy())
            labels.extend(label.numpy())

    predictions = np.array(predictions)
    labels = np.array(labels)
    return roc_auc_score(labels, predictions)

# %%
# 交叉验证
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# %%
auc_scores = []
for train_index, test_index in kf.split(graph_data_list):
    train_data = [graph_data_list[i] for i in train_index]
    test_data = [graph_data_list[i] for i in test_index]

    train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_data, batch_size=32, shuffle=False)

    # 初始化模型、优化器和损失函数
    model = GraphBinaryClassificationNetWithEdgeFeatures()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    crit = torch.nn.BCEWithLogitsLoss()  # 使用 BCEWithLogitsLoss

    # 训练模型
    for epoch in range(10):
        train_loss = train(train_loader, model, optimizer, crit)

    # 评估模型
    auc_score = evaluate(test_loader, model)
    auc_scores.append(auc_score)
    print(f"Fold AUC Score: {auc_score}")
# Out:
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.6934727731698521
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.7176724137931034
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.8711063372717508
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.7024066091954022
# D:\anaconda3\envs\DL\lib\site-packages\torch_geometric\deprecation.py:22: UserWarning: 'data.DataLoader' is deprecated, use 'loader.DataLoader' instead
#   warnings.warn(out)
# Fold AUC Score: 0.7654784240150094

# %%
# 计算平均 AUC 分数
avg_auc_score = np.mean(auc_scores)
print("Average AUC Score:", avg_auc_score)
# Out:
# Average AUC Score: 0.7500273114890236

# %%
for session_id in tqdm(node_df['sessionId'].unique()):
    # 节点特征
    session_nodes = node_df[node_df['sessionId'] == session_id]
    node_features = session_nodes[['degree','cluster', 'efficiency']].values
    
    # 对节点特征进行标准化
    scaler = StandardScaler()
    node_features_normalized = scaler.fit_transform(node_features)
    
    # 将标准化后的特征转换为 PyTorch 张量
    node_features_tensor = torch.tensor(node_features_normalized, dtype=torch.float)

    # 边索引
    session_edges = links_df[links_df['sessionId'] == session_id]
    edge_index = torch.tensor([session_edges['source'].values - 1, 
                               session_edges['target'].values - 1], 
                              dtype=torch.long)

    # 边特征
    edge_features = edge_feature_df[edge_feature_df['sessionId'] == session_id]['edge_feature'].values
    
    # 对边特征进行标准化
    edge_scaler = StandardScaler()
    edge_features_normalized = edge_scaler.fit_transform(edge_features.reshape(-1, 1))
    
    # 将标准化后的边特征转换为 PyTorch 张量
    edge_attr_tensor = torch.tensor(edge_features_normalized, dtype=torch.float)

    # 标签
    label = labels_df[labels_df['sessionId'] == session_id]['label'].iloc[0]
    label_tensor = torch.tensor([label], dtype=torch.float)

    # 创建图数据对象
    data = Data(x=node_features_tensor, edge_index=edge_index, y=label_tensor, edge_attr=edge_attr_tensor)
    graph_data_list.append(data)
